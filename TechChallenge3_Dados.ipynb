# %% [markdown]
# Parte 1 - Carregar e preparar os dados

# %%
#Conexão com o Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import pandas as pd
import re

# %%
# Lista para armazenar todos os dados processados
json_new = []

# Processar dados do arquivo JSON Lines do dataset complementar
with open(r'/content/drive/MyDrive/Colab Notebooks/trn.json', 'r', encoding='utf-8') as file:
    json_new = []

    for line in file:
      try:
        item = json.loads(line)
        new_item = {
            "title": item["title"],
            "content": item["content"]
        }
        json_new.append(new_item)
      except json.JSONDecodeError as e:
       print(f"Skipping invalid line: {line.strip()} due to error: {e}")

df = pd.DataFrame(json_new)
print(df.head())
# Out:
# Skipping invalid line: {"uid": "B005VLMEN4", "title": "", "content": "The GLX 104 series has a destinct copter sytle look with an lightweight ABS thermoplastic resign shell, plush interior and a unique shield and base plate making it one of a kind. A removable neck curtain has also been added for all riding conditions and better comfort in warm and cool climates. It is available in 8 different color options in s due to error: Unterminated string starting at: line 1 column 47 (char 46)
#                                                title  \
# 0                        Girls Ballet Tutu Neon Pink
# 1                           Adult Ballet Tutu Yellow
# 2  The Way Things Work: An Illustrated Encycloped...
# 3                                      Mog's Kittens
# 4                              Misty of Chincoteague
#
#                                              content
# 0  High quality 3 layer ballet tutu. 12 inches in...
# 1
# 2
# 3  Judith Kerr&#8217;s best&#8211;selling adventu...
# 4

# %%
df.shape
# Out:
# (1499649, 2)

# %%
df.head(50)
# Out:
#                                                 title  \
# 0                         Girls Ballet Tutu Neon Pink
# 1                            Adult Ballet Tutu Yellow
# 2   The Way Things Work: An Illustrated Encycloped...
# 3                                       Mog's Kittens
# 4                               Misty of Chincoteague
# 5   Hilda Boswell's treasury of children's stories...
# 6   The Simple Truths of Service: Inspired by John...
# 7                         Girls Ballet Tutu Neon Blue
# 8   Evaluating Research in Academic Journals - A P...
# 9   Dr. Seuss ABC (Dr.Seuss Classic Collection) (S...
# 10                          Noddy Story Book Treasury
# 11                                 The Book of Daniel
# 12                                        The Prophet
# 13                          Rightly Dividing the Word
# 14  Mksap 16 Audio Companion: Medical Knowledge Se...
# 15                        Worship with Don Moen [VHS]
# 16                         Autumn Story Brambly Hedge
# 17  Spirit Led-Moving By Grace In The Holy Spirit'...
# 18               The Very Bad Bunny (Beginner Series)
# 19      The Bayeux Tapestry: The Norman Conquest 1066
# 20            Hilda Boswell's Treasury of Fairy Tales
# 21                           Tales from Brambly Hedge
# 22                                      Nice for Mice
# 23                             The Book of Revelation
# 24                                Crash of Hennington
# 25  The Collected Short Stories of Louis L'Amour -...
# 26        Do Look Out, Noddy! (Noddy Classic Library)
# 27                            For Whom the Bell Tolls
# 28                               In the Shadow of Man
# 29  Apple A Day: The Myths, Misconceptions and Tru...
# 30  The Collected Short Stories of Louis L'amour (...
# 31      GOLD DIGGERS~STRIKING IT RICH IN THE KLONDIKE
# 32       Noddy at the Seaside (Noddy Classic Library)
# 33                          Exodus to a Hidden Valley
# 34                     Paris: City of Light 1919-1939
# 35                    Little Black Goes to the Circus
# 36                         On Happiness, U.S. Edition
# 37                             Infallible? An Inquiry
# 38  France: The Beautiful Cookbook- Authentic Reci...
# 39      George MacLeod: Founder of the Iona Community
# 40                    A Day in the Life of California
# 41                  Time and Chance: An Autobiography
# 42  Mexico The Beautiful Cookbook: Authentic Recip...
# 43                         A Day in the Life of China
# 44                    America: The Beautiful Cookbook
# 45                         Paris on the Eve 1900-1914
# 46  California, The Beautiful Cookbook: Authentic ...
# 47  A Day in the Life of Italy: Photographed by 10...
# 48                                            Memoirs
# 49                              The Life of My Choice
#
#                                               content
# 0   High quality 3 layer ballet tutu. 12 inches in...
# 1
# 2
# 3   Judith Kerr&#8217;s best&#8211;selling adventu...
# 4
# 5
# 6
# 7   Dance tutu for girls ages 2-8 years. Perfect f...
# 8
# 9
# 10
# 11
# 12  In a distant, timeless place, a mysterious pro...
# 13         --This text refers to thePaperbackedition.
# 14
# 15                        Worship with Don Moen [VHS]
# 16  "!the most research-crammed fantasy ever set b...
# 17  You can flow effortlessly and powerfully in th...
# 18     By Marilyn Sadler, Illustrated by Roger Bollen
# 19
# 20
# 21
# 22  Jill Barklem was born in Epping in 1951. After...
# 23  American Baptist pastor, Bible teacher, and wr...
# 24
# 25
# 26
# 27
# 28  "An instant animal classic."   --Time"Apart fr...
# 29  Widely known in Canada from hisMontreal Gazett...
# 30
# 31
# 32
# 33
# 34
# 35
# 36                Text: English, French (translation)
# 37  Text: English (translation)Original Language: ...
# 38  Though at first glance too luscious for the po...
# 39
# 40
# 41
# 42  The latest addition to this popular series is ...
# 43  Ninety photographers (60 Western, 30 Chinese) ...
# 44  Fifth in the series that includes the best-sel...
# 45  In pre-WW I Paris, Picasso, Debussy, Gide, Pro...
# 46  Two collections of California's best. The late...
# 47  Tenth in the Day in the Life series, this phot...
# 48
# 49  Perhaps the last of the great romantic gentlem...

# %%
# Remover linhas com valores nulos em 'title' ou 'content'
df = df[(df['title'].str.strip() != '') & (df['content'].str.strip() != '')]

print('Removida as linhas com valores nulos em title ou content')

# Remover entradas duplicadas
df = df.drop_duplicates(subset=['title', 'content'])
print('Removida entradas duplicadas')

# Remover caracteres especiais
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text.strip().lower())
    return text
print('Removido os caracteres especiais')

# Aplicar função de limpeza
df['title'] = df['title'].apply(clean_text)
df['content'] = df['content'].apply(clean_text)
print('Aplicada função de limpeza')

# Remover descrições muito curtas
df = df[df['content'].str.split().str.len() > 5]
print('Removida descrições muito curtas')
# Out:
# Removida as linhas com valores nulos em title ou content
# Removida entradas duplicadas
# Removido os caracteres especiais
# Aplicada função de limpeza
# Removida descrições muito curtas

# %%
df.shape
# Out:
# (955366, 2)

# %%
df.head(50)
# Out:
#                                                  title  \
# 0                          girls ballet tutu neon pink
# 3                                         mogs kittens
# 7                          girls ballet tutu neon blue
# 12                                         the prophet
# 16                          autumn story brambly hedge
# 17   spirit ledmoving by grace in the holy spirits ...
# 18                  the very bad bunny beginner series
# 22                                       nice for mice
# 23                              the book of revelation
# 28                                in the shadow of man
# 29   apple a day the myths misconceptions and truth...
# 38   france the beautiful cookbook authentic recipe...
# 42   mexico the beautiful cookbook authentic recipe...
# 43                          a day in the life of china
# 44                      america the beautiful cookbook
# 45                           paris on the eve 19001914
# 46   california the beautiful cookbook authentic re...
# 47   a day in the life of italy photographed by 100...
# 49                               the life of my choice
# 50   the wall images and offerings from the vietnam...
# 56                         a day in the life of canada
# 57   birds of britain and europe with north africa ...
# 58                        a day in the life of ireland
# 61   harvey penicks little red golf book lessons an...
# 62                      city of djinns a year in delhi
# 67   italy the beautiful cookbook authentic recipes...
# 72                                      the black moon
# 73                              the shadow of the lynx
# 75                                           harlequin
# 79                   the loving cup the poldark novels
# 81                           balsamic vinegar cookbook
# 82                               the mauritius command
# 84   scones muffins and tea cakes breakfast breads ...
# 86   flashman and the redskins from the flashman pa...
# 90                          mermaids nymphs of the sea
# 91                        the best of clay pot cooking
# 92                                              circus
# 93                                     the golden gate
# 94                            miss marples final cases
# 95                                   the last frontier
# 98                         asia the beautiful cookbook
# 99                             problem at pollensa bay
# 100                    thailand the beautiful cookbook
# 101                                 the best of mexico
# 102                 potatoes a country garden cookbook
# 105                   apples a country garden cookbook
# 106                 tomatoes a country garden cookbook
# 107                             passenger to frankfurt
# 108                     roy rogers king of the cowboys
# 109                  berries a country garden cookbook
#
#                                                content
# 0    high quality 3 layer ballet tutu 12 inches in ...
# 3    judith kerr8217s best8211selling adventures of...
# 7    dance tutu for girls ages 28 years perfect for...
# 12   in a distant timeless place a mysterious proph...
# 16   the most researchcrammed fantasy ever set befo...
# 17   you can flow effortlessly and powerfully in th...
# 18       by marilyn sadler illustrated by roger bollen
# 22   jill barklem was born in epping in 1951 after ...
# 23   american baptist pastor bible teacher and writ...
# 28   an instant animal classic   timeapart from its...
# 29   widely known in canada from hismontreal gazett...
# 38   though at first glance too luscious for the po...
# 42   the latest addition to this popular series is ...
# 43   ninety photographers 60 western 30 chinese fan...
# 44   fifth in the series that includes the bestsell...
# 45   in preww i paris picasso debussy gide proust h...
# 46   two collections of californias best the latest...
# 47   tenth in the day in the life series this photo...
# 49   perhaps the last of the great romantic gentlem...
# 50   this volume to be published on the fifth anniv...
# 56   like the similar books about australia hawaii ...
# 57   brilliantly organised guide  beautiful apparen...
# 58   on one day in may 1991 more than 75 distinguis...
# 61   before titanium drivers before oversized heads...
# 62   delhi has a richly layered past and dalrymple ...
# 67   lorenza de medici has published more than 30 c...
# 72   from the incomparable winston grahamwho has ev...
# 73   for a good escapist read victoria holt never d...
# 75   morris west an australian by birth has lived i...
# 79   from the incomparable winston grahamwho has ev...
# 81   an estimated 175 million liters of commercial ...
# 82   ashore without a commandand on halfpay to boot...
# 84   a beautifully photographed and affordably pric...
# 86   if ever there was a time when i felt that watc...
# 90   mermaids embody all that is beautiful wondrous...
# 91   this wonderful series is the easiest way to sa...
# 92   great reading sunday telegraph an actionpacked...
# 93   startlingly goodtenseingenious sunday express ...
# 94   when it all becomes clear as day the reader ca...
# 95   breathless bloody and detailed daily telegraph...
# 98   each title in this awardwinning series offers ...
# 99   dame agatha christies prolific output of novel...
# 100  panurat poladitmontri chefowner of the lemon g...
# 101  this wonderful series is the easiest way to sa...
# 102  waldrone  cold spaghetti at midnight  here fin...
# 105  beautifully designed and exquisitely photograp...
# 106  beautifully designed and exquisitely photograp...
# 107  marvellously entertaining observer it is not a...
# 108  some things you just dont outgrow take roy rog...
# 109  beautifully designed and exquisitely photograp...

# %%
import numpy as np

# Dividir o DataFrame em 4 partes
df_split = np.array_split(df, 4)

# Salvar cada parte em um arquivo JSON separado
for i, df_part in enumerate(df_split, start=1):
    output_filename = f'/content/drive/MyDrive/Colab Notebooks/json_parte_{i}.json'
    df_part.to_json(output_filename, orient='records', lines=True, force_ascii=False)
    print(f"Parte {i} dos dados foi salva em '{output_filename}'.")
# Out:
# Parte 1 dos dados foi salva em '/content/drive/MyDrive/Colab Notebooks/json_parte_1.json'.
# Parte 2 dos dados foi salva em '/content/drive/MyDrive/Colab Notebooks/json_parte_2.json'.
# Parte 3 dos dados foi salva em '/content/drive/MyDrive/Colab Notebooks/json_parte_3.json'.
# Parte 4 dos dados foi salva em '/content/drive/MyDrive/Colab Notebooks/json_parte_4.json'.

# %%
df.shape
# Out:
# (238842, 4)

# %%
df.head()
# Out:
#                           title  \
# 0   girls ballet tutu neon pink
# 3                  mogs kittens
# 7   girls ballet tutu neon blue
# 12                  the prophet
# 16   autumn story brambly hedge
#
#                                               content  \
# 0   high quality 3 layer ballet tutu 12 inches in ...
# 3   judith kerr8217s best8211selling adventures of...
# 7   dance tutu for girls ages 28 years perfect for...
# 12  in a distant timeless place a mysterious proph...
# 16  the most researchcrammed fantasy ever set befo...
#
#                                                prompt  \
# 0   Qual a descrição em 50 caracteres do produto: ...
# 3   Qual a descrição em 50 caracteres do produto: ...
# 7   Qual a descrição em 50 caracteres do produto: ...
# 12  Qual a descrição em 50 caracteres do produto: ...
# 16  Qual a descrição em 50 caracteres do produto: ...
#
#                                              response
# 0   high quality 3 layer ballet tutu 12 inches in ...
# 3   judith kerr8217s best8211selling adventures of...
# 7   dance tutu for girls ages 28 years perfect for...
# 12  in a distant timeless place a mysterious proph...
# 16  the most researchcrammed fantasy ever set befo...
